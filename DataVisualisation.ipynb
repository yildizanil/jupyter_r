# %% [markdown]
# # Data visualisation

# %% [markdown]
# **M.Geo.336e: Digital Geoscience Seminar***
#
# Anil Yildiz, Dr. sc.
#
# E-mail: [yildiz@mbd.rwth-aachen.de](mailto:yildiz@mbd.rwth-aachen.de)
# Personal homepage: [www.anilyildiz.info](https://www.anilyildiz.info)
#
# \* *This Jupyter notebook was initially used in the Digital Geoscience Seminar at the University of Göttingen.*

# %% [markdown]
# ## Global temperature anomalies
#
# **Data:**
#
# GISTEMP Team, 2021: GISS Surface Temperature Analysis (GISTEMP), version 4. NASA Goddard Institute for Space Studies. Dataset accessed 2021-05-22 at [data.giss.nasa.gov/gistemp/](https://data.giss.nasa.gov/gistemp/")
#
# Lenssen, N., G. Schmidt, J. Hansen, M. Menne, A. Persin, R. Ruedy, and D. Zyss, 2019: Improvements in the GISTEMP uncertainty model. J. Geophys. Res. Atmos., 124, no. 12, 6307-6326, doi: [10.1029/2018JD029522](https://doi.org/10.1029/2018JD029522).

# %%
global_temp <- read.table(
    "https://data.giss.nasa.gov/gistemp/graphs/graph_data/Global_Mean_Estimates_based_on_Land_and_Ocean_Data/graph.txt",
    skip = 5)
col_global_temp <- rep(NA, nrow(global_temp))
col_global_temp[which(global_temp[, 2] < 0)] <- "#c5e9e7"
col_global_temp[which(global_temp[, 2] > 0)] <- "#ffa891"
head(global_temp)
# Out:
#   V1   V2    V3
# 1 1880 -0.15 -0.08
# 2 1881 -0.07 -0.12
# 3 1882 -0.10 -0.15
# 4 1883 -0.17 -0.19
# 5 1884 -0.27 -0.23
# 6 1885 -0.32 -0.25

# %%
options(repr.plot.width = 8, repr.plot.height = 5)
par(mar = c(3.5, 3.5, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(1880, 2021), ylim = c(-1.1, 1.1),
    xlab = NA, ylab = NA, axes = F)
segments(x0 = seq(1880, 2020, 10), y0 = -1.1,
    x1 = seq(1880, 2020, 10), y1 = 1.1, col = "gray87")
segments(x0 = 1880, y0 = seq(-1.1, 1.1, 0.1), x1 = 2020,
    y1 = seq(-1.1, 1.1, 0.1), col = "gray87")
segments(x0 = 1880, y0 = 0, x1 = 2020, y1 = 0, col = 1)
axis(1, tck = 0.02)
axis(2, tck = 0.02)
box()
lines(global_temp[, 2]~global_temp[, 1], lwd = 2, col = 1)
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Temperature anomaly [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 5)
par(mar = c(3.5, 3.5, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(1880, 2021), ylim = c(-1.1, 1.1),
    xlab = NA, ylab = NA, axes = F)
segments(x0 = seq(1880, 2020, 10), y0 = -1.1,
    x1 = seq(1880, 2020, 10), y1 = 1.1, col = "gray87")
segments(x0 = 1880, y0 = seq(-1.1, 1.1, 0.1),
    x1 = 2020, y1 = seq(-1.1, 1.1, 0.1), col = "gray87")
segments(x0 = 1880, y0 = 0,x1 = 2020, y1 = 0, col = 1)
axis(1, tck = 0.02)
axis(2, tck = 0.02)
box()
points(global_temp[, 2]~global_temp[, 1], lwd = 1, pch = 16)
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Temperature anomaly [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
positives <- global_temp[global_temp[, 2] > 0, ]
negatives <- global_temp[global_temp[, 2] < 0, ]

# %%
options(repr.plot.width = 8, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(1880, 2021), ylim = c(-1.1, 1.1),
    xlab = NA, ylab = NA, axes = F)
segments(x0 = seq(1880, 2020, 10), y0 = -1.1,
    x1 = seq(1880, 2020, 10), y1 = 1.1, col = "gray87")
segments(x0 = 1880, y0 = seq(-1.1, 1.1, 0.1),
    x1 = 2020, y1 = seq(-1.1, 1.1, 0.1), col = "gray87")
segments(x0 = 1880, y0 = 0, x1 = 2020, y1 = 0, col = 1)
axis(1, tck = 0.02)
axis(2, tck = 0.02)
box()
lines(global_temp[, 2]~global_temp[, 1], lwd = 2, col = 1)
points(negatives[, 2]~negatives[, 1], lwd = 1, bg = "#c5e9e7", pch = 21)
points(positives[, 2]~positives[, 1], lwd = 1, bg = "#ffa891", pch = 21)
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Temperature anomaly [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(1880, 2020), ylim = c(-1.1, 1.1),
    xlab = NA, ylab = NA, axes = F)
axis(1, tck = 0.02)
axis(2, tck = 0.02)
box()
polygon(x = c(global_temp[, 1], rev(global_temp[, 1])),
    y = c(ifelse(global_temp[, 2] < 0, global_temp[, 2], 0), rep(0, 141)),
    border = NA, col = "#c5e9e7")
polygon(x = c(global_temp[, 1], rev(global_temp[, 1])),
    y = c(ifelse(global_temp[, 2] > 0, global_temp[, 2], 0), rep(0, 141)),
    border = NA, col = "#ffa891")
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Temperature anomaly [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(0, 141), ylim = c(-1.1, 1.1),
    xlab = NA, ylab = NA, axes = F, pch = "")
barplot(global_temp[, 2], ylim = c(-1.1, 1.1), col = col_global_temp,
    border = NA, width = 1, xlim = c(0, 141), space = 0, axes = F, add = T)
axis(1, tck = 0.02, at = seq(0, 140, 20), labels = seq(1880, 2020, 20))
axis(2, tck = 0.02)
box()
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Temperature anomaly [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
global_temp_monthly <- read.csv(
    "https://data.giss.nasa.gov/gistemp/tabledata_v4/GLB.Ts+dSST.csv",
    header = T, skip = 1)[1:141, 1:13]
global_temp_monthly[, 2:13] <- sapply(global_temp_monthly[, 2:13], as.numeric)
temp_monthly <- t(global_temp_monthly)
head(temp_monthly)
# Out:
#      1       2       3       4       5       6       7       8       9
# Year 1880.00 1881.00 1882.00 1883.00 1884.00 1885.00 1886.00 1887.00 1888.00
# Jan    -0.17   -0.18    0.18   -0.28   -0.12   -0.57   -0.43   -0.71   -0.33
# Feb    -0.22   -0.12    0.15   -0.35   -0.07   -0.32   -0.50   -0.56   -0.35
# Mar    -0.08    0.05    0.06   -0.11   -0.36   -0.25   -0.42   -0.35   -0.41
# Apr    -0.15    0.07   -0.14   -0.17   -0.39   -0.41   -0.27   -0.34   -0.20
# May    -0.08    0.08   -0.12   -0.17   -0.33   -0.44   -0.23   -0.30   -0.21
#      10      ... 132     133     134     135     136     137     138
# Year 1889.00 ... 2011.00 2012.00 2013.00 2014.00 2015.00 2016.00 2017.00
# Jan    -0.08 ...    0.51    0.49    0.70    0.76    0.85    1.17    1.02
# Feb     0.17 ...    0.48    0.49    0.63    0.55    0.90    1.37    1.14
# Mar     0.07 ...    0.66    0.58    0.68    0.78    0.96    1.36    1.16
# Apr     0.10 ...    0.65    0.73    0.54    0.80    0.76    1.11    0.94
# ...

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(0, 141), ylim = c(-1.5, 1.5),
    xlab = NA, ylab = NA, axes = F, pch = "")
boxplot(temp_monthly, add = T, ylim = c(-1.5, 1.5),
    col = col_global_temp, axes = F)
axis(1, tck = 0.02, at = seq(0, 140, 20), labels = seq(1880, 2020, 20))
axis(2, tck = 0.02)
box()
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Temperature anomaly [°C]", side = 2, line = 2)
# Out:
# plot without title

# %% [markdown]
# ### Warming stripes by Ed Hawkins

# %% [markdown]
# **Method for visualisation:** Warming stripes by Ed Hawkins <a href="https://www.climate-lab-book.ac.uk/2018/warming-stripes/">climate-lab-book.ac.uk/2018/warming-stripes/</a>\
# **Data:** GISTEMP Team, 2021: GISS Surface Temperature Analysis (GISTEMP), version 4. NASA Goddard Institute for Space Studies. Dataset accessed 2021-05-22 at <a href="https://data.giss.nasa.gov/gistemp/">data.giss.nasa.gov/gistemp/</a>.\
# Lenssen, N., G. Schmidt, J. Hansen, M. Menne, A. Persin, R. Ruedy, and D. Zyss, 2019: Improvements in the GISTEMP uncertainty model. J. Geophys. Res. Atmos., 124, no. 12, 6307-6326, doi: <a href="https://doi.org/10.1029/2018JD029522">10.1029/2018JD029522</a>.

# %%
library(RColorBrewer)
breaks <- seq(-0.5, 1.1, length.out = 12)
options(repr.plot.width = 10, repr.plot.height = 5)
par(mar = c(0, 0, 0, 0), mgp = c(0.1, 0.1, 0),
   ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(1880, 2021), ylim = c(0, 1),
   xlab = NA, ylab = NA, axes = F)
for (i in 1:141) {
   rect(xleft = 1880 + (i - 1), ybottom = 0,
      xright = 1880 + i, ytop = 1,
      col = brewer.pal(n = 11, name = "RdBu")[12 - findInterval(global_temp[i, 2], breaks)],
      border = NA)
}
# Out:
# plot without title

# %% [markdown]
# ## Air temperature in Newcastle upon Tyne, UK

# %% [markdown]
# **Data:** Yildiz, A. & Stirling, R. 2020. PLEXUS Lysimeter Meteorological Data. doi: <a href="https://doi.org/10.25405/data.ncl.12789323.v3">10.25405/data.ncl.12789323.v3</a>.

# %%
airtemp <- read.csv("https://data.ncl.ac.uk/ndownloader/files/24194087")
airtemp[, 1] <- as.POSIXct(airtemp[, 1], tz = "UTC", format = "%d/%m/%Y %H:%M")
summary(airtemp)
# Out:
#       Time                        AirTemp
#  Min.   :2019-05-03 00:15:00   Min.   : 2.50
#  1st Qu.:2019-05-22 00:07:30   1st Qu.:10.40
#  Median :2019-06-10 00:00:00   Median :13.40
#  Mean   :2019-06-10 00:00:00   Mean   :13.04
#  3rd Qu.:2019-06-28 23:52:30   3rd Qu.:15.70
#  Max.   :2019-07-17 23:45:00   Max.   :25.70

# %%
start <- as.POSIXct("2019-05-03 00:00", tz = "UTC")
end <- as.POSIXct("2019-07-18 00:00", tz = "UTC")

# %%
time_steps_24h <- seq(start, end, 60 * 60 * 24)
which_step_24h <- findInterval(as.POSIXct(airtemp[, 1], tz = "UTC"),
    time_steps_24h)
airtemp_24h <- aggregate(airtemp[, 2], list(time_steps_24h[which_step_24h]),
    mean, na.rm = T)
airtemp_max <- aggregate(airtemp[, 2], list(time_steps_24h[which_step_24h]),
    max, na.rm = T)
airtemp_min <- aggregate(airtemp[, 2], list(time_steps_24h[which_step_24h]),
    min, na.rm = T)
axis_steps_24h <- seq(start + 60 * 60 * 12, end, 60 * 60 * 24)
head(airtemp_24h)
# Out:
#   Group.1    x
# 1 2019-05-03 6.372632
# 2 2019-05-04 5.907292
# 3 2019-05-05 7.477083
# 4 2019-05-06 6.428125
# 5 2019-05-07 6.484375
# 6 2019-05-08 7.384375

# %%
axis_days <- seq(start, end, 60 * 60 * 24)
axis_weeks <- seq(start, end, 60 * 60 * 24 * 7)
axis_week_names <- paste0(substr(axis_weeks, 9, 10), "-",
    substr(axis_weeks, 6, 7))

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(start, end), ylim = c(0, 30),
    xlab = NA, ylab = NA, axes = F)
segments(x0 = axis_days, y0 = 0,
    x1 = axis_days, y1 = 30,
    col = "gray87")
segments(x0 = start, y0 = seq(0, 30, 5),
    x1 = end, y1 = seq(0, 30, 5), col = "gray87")
axis(1, tck = 0.01, at = axis_days, labels = NA)
axis(1, tck = 0.02, at = axis_weeks, labels = axis_week_names)
axis(2, tck = 0.02)
box()
lines(airtemp$AirTemp~airtemp$Time, lwd = 2)
par(las = 0)
mtext("Time [dd-mm-2019]", side = 1, line = 2)
mtext("Air temperature [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(start, end), ylim = c(0, 30),
    xlab = NA, ylab = NA, axes = F)
segments(x0 = axis_days, y0 = 0,
    x1 = axis_days, y1 = 30,
    col = "gray87")
segments(x0 = start, y0 = seq(0, 30, 5),
    x1 = end, y1 = seq(0, 30, 5),
    col = "gray87")
axis(1, tck = 0.01, at = axis_days, labels = NA)
axis(1, tck = 0.02, at = axis_weeks, labels = axis_week_names)
axis(2, tck = 0.02)
box()
lines(airtemp$AirTemp~airtemp$Time, lwd = 2, col = 8)
points(airtemp_24h[, 2]~axis_steps_24h, col = 2, pch = 16)
par(las = 0)
mtext("Time [dd-mm-2019]", side = 1, line = 2)
mtext("Air temperature [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(start, end), ylim = c(0, 30),
    xlab = NA, ylab = NA, axes = F)
segments(x0 = axis_days, y0 = 0,
    x1 = axis_days, y1 = 30,
    col = "gray87")
segments(x0 = start, y0 = seq(0, 30, 5),
    x1 = end, y1 = seq(0, 30, 5),
    col = "gray87")
axis(1, tck = 0.01, at = axis_days, labels = NA)
axis(1, tck = 0.02, at = axis_weeks, labels = axis_week_names)
axis(2, tck = 0.02)
box()
lines(airtemp_24h[, 2]~axis_steps_24h, col = 2, lwd = 2)
points(airtemp_24h[, 2]~axis_steps_24h, col = 2, pch = 16)
par(las = 0)
mtext("Time [dd-mm-2019]", side = 1, line = 2)
mtext("Air temperature [°C]", side = 2, line = 2)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
    ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(start, end), ylim = c(0, 30),
    xlab = NA, ylab = NA, axes = F)
segments(x0 = axis_days, y0 = 0,
    x1 = axis_days, y1 = 30,
    col = "gray87")
segments(x0 = start, y0 = seq(0, 30, 5),
    x1 = end, y1 = seq(0, 30, 5),
    col = "gray87")
axis(1, tck = 0.01, at = axis_days, labels = NA)
axis(1, tck = 0.02, at = axis_weeks, labels = axis_week_names)
axis(2, tck = 0.02)
box()
lines(airtemp_24h[, 2]~axis_steps_24h, col = 2, lwd = 2)
points(airtemp_24h[, 2]~axis_steps_24h, bg = 2, pch = 21)
polygon(x = c(axis_steps_24h, rev(axis_steps_24h)),
    y = c(airtemp_max[, 2], rev(airtemp_min[, 2])),
    col = rgb(1, 0, 0, 0.3), border = NA)
par(las = 0)
mtext("Time [dd-mm-2019]", side = 1, line = 2)
mtext("Air temperature [°C]", side = 2, line = 2)
# Out:
# plot without title

# %% [markdown]
# ## Energy consumption in Leipzig

# %% [markdown]
# **Data:** <a href="https://statistik.leipzig.de/opendata/api/values?kategorie_nr=13&rubrik_nr=4&periode=y&format=csv">Energieverbrauch (Jahreszahlen)</a> by <a href="https://opendata.leipzig.de/">Stadt Leipzig</a> is licensed under <a href="https://www.govdata.de/dl-de/by-2-0">DL-DE/BY-2.0.</a>
#  <br>

# %%
leipzig <- read.csv(
    "https://statistik.leipzig.de/opendata/api/values?kategorie_nr=13&rubrik_nr=4&periode=y&format=csv")
head(leipzig)
leipzig <- leipzig[seq(3, 12, 2), 1:17]
# Out:
#   Kennziffer                                  Einheit X2000 X2001 X2002 X2003
# 1 Endenergieverbrauch insgesamt               NA      7350  6800  7080  6716
# 2 darunter Haushalte                          NA      3398  3564  3392  3497
# 3 Strom/Nahstrom (einschl. regenerativ)       NA      1799  1980  2278  2010
# 4 darunter Haushalte                          NA       485   574   574   577
# 5 FernwÃ¤rme/NahwÃ¤rme (einschl. regenerativ) NA      1669  1779  1771  1616
# 6 daruner Haushalte                           NA       834   784   671   671
#   X2004 X2005 X2006 X2007 X2008 X2009 X2010 X2011 X2012 X2013 X2014
# 1 6990  7050  7087  6390  6622  6296  6879  6403  6609  7286  6370
# 2 3455  3348  3495  3390  3381  3178  2598  2791  2912  3065  2625
# 3 2018  2169  2315  2135  2165  2094  2079  2129  2154  2184  2256
# 4  580   576   567   544   524   507   503   515   521   528   546
# 5 1704  1622  1583  1284  1313  1367  1611  1325  1424  1546  1268
# ...

# %%
data <- as.matrix(leipzig[, 3:17])
for (i in 1:15) {
 data[, i] <- 100 * data[, i] / sum(data[, i])
 }
 head(data)
# Out:
#    X2000     X2001     X2002     X2003     X2004     X2005     X2006
# 3  24.476190 29.117647 32.166055 29.928529 28.869814 30.765957 32.665444
# 5  22.707483 26.161765 25.007060 24.061942 24.377682 23.007092 22.336673
# 7  29.795918 35.235294 34.326461 36.986301 38.097282 38.141844 38.267250
# 9   4.802721  4.632353  3.967806  4.109589  3.776824  3.205674  2.723296
# 11 18.217687  4.852941  4.532618  4.913639  4.878398  4.879433  4.007337
#    X2007     X2008     X2009     X2010     X2011     X2012     X2013
# 3  33.411581 32.689114 33.259212 30.226810 33.250039 32.591920 29.975295
# 5  20.093897 19.824853 21.712198 23.422507 20.693425 21.546376 21.218776
# 7  39.374022 40.495244 37.627065 39.226519 39.543964 39.567257 42.698326
# 9   2.832551  2.763098  3.081321  3.096830  2.826800  2.708428  2.676366
# 11  4.287950  4.227691  4.320203  4.027334  3.685772  3.586019  3.431238
#    X2014
# 3  35.410454
# 5  19.902684
# 7  39.114739
# 9   2.181761
# 11  3.390363

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
layout(matrix(c(1, 2), nrow = 2, ncol = 1), widths = c(16), heights = c(1, 7))
par(mar = c(0, 0, 0, 0), mgp = c(0.1, 0.1, 0),
       ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, type = "l", ylim = c(0, 50), xlim = c(2000, 2014),
       pch = "", axes = F, xlab = NA, ylab = NA)
legend("center",
       c("Electricity", "District heating", "Natural gas",
              "Coal", "Heating oil"),
       ncol = 3, lwd = 2,
       col = c("#ffcc91", "#ef7b61", "#c64022", "#afc6f3", "#31738a"),
       bty = "n", pch = c(1, 0, 16, 8, 15))
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
       ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, type = "l", ylim = c(0, 50), xlim = c(2000, 2014),
       pch = "", axes = F, xlab = NA, ylab = NA)
segments(x0 = seq(2000, 2014, 1), y0 = 0,
       x1 = seq(2000, 2014, 1), y1 = 50, col = "gray87")
segments(x0 = 2000, y0 = seq(0, 50, 5),
       x1 = 2014, y1 = seq(0, 50, 5), col = "gray87")
axis(1, tck = 0.02)
axis(2, tck = 0.02)
lines(data[1, ]~seq(2000, 2014, 1), lwd = 2,
       col = "#ffcc91", type = "b", pch = 1)
lines(data[2, ]~seq(2000, 2014, 1), lwd = 2,
       col = "#ef7b61", type = "b", pch = 0)
lines(data[3, ]~seq(2000, 2014, 1), lwd = 2,
       col = "#c64022", type = "b", pch = 16)
lines(data[4, ]~seq(2000, 2014, 1), lwd = 2,
       col = "#afc6f3", type = "b", pch = 8)
lines(data[5, ]~seq(2000, 2014, 1), lwd = 2,
       col = "#31738a", type = "b", pch = 15)
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Share of energy consumption [%]", side = 2, line = 2)
box()
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
layout(matrix(c(1, 2), nrow = 2, ncol = 1), widths = c(16), heights = c(1, 7))
par(mar = c(0, 0, 0, 0), mgp = c(0.1, 0.1, 0),
       ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, type = "l", ylim = c(0, 50), xlim = c(2000, 2014),
       pch = "", axes = F, xlab = NA, ylab = NA)
legend("center",
       c("Electricity", "District heating", "Natural gas",
              "Coal", "Heating oil"),
       ncol = 3,
       col = c("#ffcc91", "#ef7b61", "#c64022", "#afc6f3", "#31738a"),
       bty = "n", pch = c(15))
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
       ps = 14, family = "serif", las = 1, pty = "m")
barplot(data,
       col = c("#ffcc91", "#ef7b61", "#c64022", "#afc6f3", "#31738a"),
       space = 0.1, names.arg = seq(2000, 2014, 1), axes = F)
axis(2, tck = 0.02)
box()
par(las = 0)
mtext("Year", side = 1, line = 3.5)
mtext("Share of energy consumption [%]", side = 2, line = 2)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
layout(matrix(c(1, 2), nrow = 2, ncol = 1), widths = c(16), heights = c(1, 7))
par(mar = c(0, 0, 0, 0), mgp = c(0.1, 0.1, 0),
       ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, type = "l", ylim = c(0, 50), xlim = c(2000, 2014),
       pch = "", axes = F, xlab = NA, ylab = NA)
legend("center",
       c("Electricity", "District heating", "Natural gas",
              "Coal", "Heating oil"),
       ncol = 3,
       col = c("#ffcc91", "#ef7b61", "#c64022", "#afc6f3", "#31738a"),
       bty = "n", pch = c(15))
par(mar = c(3.5, 4, 0.25, 0.25), mgp = c(0.1, 0.1, 0),
       ps = 14, family = "serif", las = 1, pty = "m")
plot(0, 0, xlim = c(2000, 2014), ylim = c(0, 100),
       xlab = NA, ylab = NA, axes = F)
polygon(x = c(c(2000:2014), c(2014:2000)),
       y = c(data[1, ], rep(0, 15)),
       col = "#ffcc91", border = NA)
polygon(x = c(c(2000:2014), c(2014:2000)),
       y = c(data[2, ] + data[1, ], rev(data[1, ])),
       col = "#ef7b61", border = NA)
polygon(x = c(c(2000:2014), c(2014:2000)),
       y = c(data[3, ] + data[2, ] + data[1, ], rev(data[2, ] + data[1, ])),
       col = "#c64022", border = NA)
polygon(x = c(c(2000:2014), c(2014:2000)),
       y = c(data[4, ] + data[3, ] + data[2, ] + data[1, ],
              rev(data[3, ] + data[2, ] + data[1, ])),
       col = "#afc6f3", border = NA)
polygon(x = c(c(2000:2014), c(2014:2000)),
       y = c(data[5, ] + data[4, ] + data[3, ] + data[2, ] + data[1, ],
              rev(data[4, ] + data[3, ] + data[2, ] + data[1, ])),
       col = "#31738a", border = NA)
axis(1, tck = 0.02, at = seq(2000, 2014, 1))
axis(2, tck = 0.02)
par(las = 0)
mtext("Year", side = 1, line = 1.5)
mtext("Share of energy consumption [%]", side = 2, line = 2)
box()
# Out:
# plot without title
